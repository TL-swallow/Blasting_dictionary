# %% [markdown]
# <a href="https://colab.research.google.com/github/TL-swallow/Blasting_dictionary/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# coding:utf-8
from urllib import request
import re
import time
import _thread

def getdata(page):
	url = 'http://www.mp4ba.com/dianying/list_'+str(page)+'.html'
	header = {'User-agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.168 Safari/537.36'}
	req = request.Request(url,headers=header)
	html = request.urlopen(req).read().decode('utf-8')
	#print(html)
	ru = re.compile('<a href="(.*?)" title="(.*?)" target="_blank" >.*</a><span>(.*?)</span>')
	items = re.findall(ru,html)
	for item in items:
		yield{
			'date':item[2],
			'titiel':item[1],
			'href':item[0],
		}

def main():

	for page in range(1,48):
		print('第%s页' %page)
		for i in range(10,-1,-1):
			print('\r','距离开始还有 %s 秒! \n' % str(i).zfill(2),end='')
			time.sleep(1)
			getdata(page)
		for item in getdata(page):
			print(item) 

if __name__ == '__main__':
	main()
# Out:
# 第1页
#  距离开始还有 10 秒!
#  距离开始还有 09 秒!
#  距离开始还有 08 秒!
#  距离开始还有 07 秒!
#  距离开始还有 06 秒!
#  距离开始还有 05 秒!
#  距离开始还有 04 秒!
#  距离开始还有 03 秒!
#  距离开始还有 02 秒!
#  距离开始还有 01 秒!
#  距离开始还有 00 秒!
# {'date': '[2019-05-16]', 'titiel': '遗孀秘闻HD英语中英双字', 'href': 'http://www.mp4ba.com/juqingpian/1007.html'}
# {'date': '[2019-05-16]', 'titiel': '博尔登HD英语中英双字', 'href': 'http://www.mp4ba.com/juqingpian/1006.html'}
# {'date': '[2019-05-16]', 'titiel': '狗狗情缘BD德语中字', 'href': 'http://www.mp4ba.com/juqingpian/1005.html'}
# {'date': '[2019-05-16]', 'titiel': '欲念游戏HD国语中英双字', 'href': 'http://www.mp4ba.com/kehuanpian/1004.html'}
# {'date': '[2019-05-16]', 'titiel': '转型团伙HD国语中英双字', 'href': 'http://www.mp4ba.com/xijupian/1002.html'}
# {'date': '[2019-05-16]', 'titiel': '转型团伙HD4K国语中英双字', 'href': 'http://www.mp4ba.com/4k/1001.html'}
# {'date': '[2019-05-16]', 'titiel': '欲念游戏HD4K国语中英双字', 'href': 'http://www.mp4ba.com/4k/1003.html'}
# ...

# %% [markdown]
# # 新段落
